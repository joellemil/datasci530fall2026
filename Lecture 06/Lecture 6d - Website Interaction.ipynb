# %% [markdown]
# # <span style="color:darkblue"> Lecture 6d - Website Interaction </span>

# %% [markdown]
# <font size = "5">
#
# Import packages for data processing + web scraping

# %%
# This command executes the python scripts
exec(open("./scripts/import_packages.py").read())

# %% [markdown]
# # <span style="color:darkblue"> I. Initialize Web Driver </span>

# %%
# Open browser to start web scraping
options = webdriver.ChromeOptions()
options.headless = False 
driver = webdriver.Chrome(options=options)

# Navigate to specific website
starting_url = 'https://atlas.emory.edu'
driver.get(starting_url)

# %% [markdown]
# # <span style="color:darkblue"> II. Interact with forms </span>

# %% [markdown]
# <font size = "5">
#
# Emory's Course Atlas website has a searchable form <br>

# %% [markdown]
# <font size = "5">
#
#
# <img src="figures/screenshot_courseatlas_form.png" alt="drawing" width="200"/>

# %% [markdown]
# <font size = "5">
#
# Find a form element
#
# <font size = "3">
#
# - Here we search by tag and attribute value
# - You can find the "xpath" by going into Developer Tools in Google Chrome

# %%
form_semester = driver.find_element('xpath','//select[@id="crit-srcdb"]')

# %% [markdown]
# <font size = "5">
#
# Convert to form
#
# <img src="figures/screenshot_semester_form.png" alt="drawing" width="200"/>
#
# <font size = "3">
#
# - Must convert HTML element suing ```Select()``` function to <br>
# enable interactive form capabilities
# - Extract the displayed option values with  ```.text``` for each element <br>
# or the internal HTML values with
# - We extract the options using a loop

# %%
# "Select" is a function from the selenium package
# ".options" extracts the options for Selenium
select_semester = Select(form_semester)
store_options   = select_semester.options
num_options     = len(store_options)

# Store options into a list
list_options = []
for i in range(num_options):
    # This extracts the displayed to 
    option_text = store_options[i].text    
    
    # This extracts the internal HTML values
    # Uncomment this line to display option values instead of displayed text
    # option_text = store_options[i].get_attribute("value")
    list_options.append( option_text )   

list_options
# Out:
# ['Fall 2026',
#  'Summer 2026',
#  'Spring 2026',
#  'Fall 2025',
#  'Summer 2025',
#  'Spring 2025',
#  'Fall 2024',
#  'Summer 2024',
#  'Spring 2024',
#  'Fall 2023',
#  'Summer 2023',
#  'Spring 2023',
#  'Fall 2022',
#  'Summer 2022',
#  'Spring 2022',
#  'Fall 2021',
#  'Summer 2021',
#  'Spring 2021',
#  'Fall 2020',
#  'Summer 2020',
#  'Spring 2020',
#  'Fall 2019',
#  'Summer 2019',
#  'Spring 2019']

# %% [markdown]
# <font size = "5">
#
# Select an option
#
# <font size = "3">
#
# - The code displays three equivalent ways of selecting the value <br>
# - Once you run this line you should see the Google Chrome browser <br>
# interactively select that option, as though you had clicked on it

# %%
# Select by visible text
select_semester.select_by_visible_text('Spring 2024')

# select_semester.select_by_index(2)
# select_semester.select_by_value('5241')

# %% [markdown]
# <font size = "5">
#
# Type text into a search form
#
# <font size = "3">
#
# - Double check on the browser to see that the information <br>
# was entered.

# %%
# Find element to enter text
form_search = driver.find_element('xpath','//input[@id = "crit-keyword"]') 

# Clear the text before typing anything
form_search.clear()

# Type something on the screen in the location of that particular element
form_search.send_keys("qtm")

# %% [markdown]
# <font size = "5">
#
# Mimic entering "Return" on the keyboard

# %%
# "Keys" is a Python object that stands for keyboard
form_search.send_keys(Keys.RETURN)

# %% [markdown]
# <font size = "5">
#
# Click on an element

# %%
# Find element
form_button = driver.find_element('xpath','//*[@id="search-button"]') 

# Click on element
# Note: Here the element that we choose happens to be a button, but 
# in general you can click on any element, the same way you would do 
# as a user.
form_button.click()

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# <font size = "3">
#
# - Find the ``` xpath ``` for the drop-down list "Any Career"
# - Select the option "Emory College"
# - Send the form

# %%
# Write your own code

form_career = driver.find_element('xpath','//select[@id="crit-career"]')

# "Select" is a function from the selenium package
# ".options" extracts the options for Selenium
select_career = Select(form_career)
store_options   = select_career.options
num_options     = len(store_options)

# Store options into a list
list_options = []
for i in range(num_options):
    # This extracts the displayed to 
    option_text = store_options[i].text    
    
    # This extracts the internal HTML values
    # Uncomment this line to display option values instead of displayed text
    # option_text = store_options[i].get_attribute("value")
    list_options.append( option_text )   

print(list_options)

# Select career
select_career.select_by_visible_text('Emory College')


# Find element
form_button = driver.find_element('xpath','//*[@id="search-button"]') 

# Click on element
# Note: Here the element that we choose happens to be a button, but 
# in general you can click on any element, the same way you would do 
# as a user.
form_button.click()
# Out:
# ['Any Career', 'Emory College', 'Graduate Allied Health', 'Graduate Business', 'Graduate Nursing', 'Graduate School', 'Law', 'Medicine', 'Oxford College', 'Public Health', 'Theology', 'Undergraduate Allied Health', 'Undergraduate Business', 'Undergraduate Nursing']

# %% [markdown]
# # <span style="color:darkblue"> III. Interact and Extract Data </span>

# %% [markdown]
# <font size = "5">
#
# Some content is only available after interaction
#
# <font size = "3">
#
# - For example, in the course Atlas, some information becomes visible <br>
# after you search.
# - You need to make sure that the Python code mimics the process <br>
# you would use if you were to navigate the website.

# %% [markdown]
# <font size = "5">
#
# Enter text in a form

# %%
form_search = driver.find_element('xpath','//input[@id = "crit-keyword"]') 
form_search.clear()
form_search.send_keys("computing")
form_search.send_keys(Keys.RETURN)

# %% [markdown]
# <font size = "5">
#
# Extract list of resulting options
#
# <font size = "3">
#
# - Find "xpath" by browsing the website in Developer mode

# %%
list_results = driver.find_elements('xpath','//div[@class = "result result--group-start"]') 

# Check number of results
num_results = len(list_results)
print(num_results)
# Out:
# 41

# %% [markdown]
# <font size = "5">
#
# Extract information of a particular search result
#
# <font size = "3">
#
# - Conduct search for tags + attributes on subelements
# - Use ```.text()``` to extract content
# - In this example we are searching for attributes called "result_code" <br>
# and "result__title". These names just appear for this Emory website example. <br>
# In this example we are also extracting an HTML tag of type "span".

# %%
emory_coursecode = list_results[0].find_element('xpath','//span[@class = "result__code"] ').text
emory_classname  = list_results[0].find_element('xpath','//span[@class = "result__title"] ').text

print(emory_coursecode)
print(emory_classname)
# Out:
# CS 110
# Computer Science Fundamentals

# %% [markdown]
# <font size = "5">
#
# Store extracted data
#
# <font size = "3">
#
# - Conduct search for tags + attributes on subelements
# - Use ```.text()``` to extract content
# - In this example we are searching for attributes called "result_code" <br>
# and "result__title". These names just appear for this Emory website example. <br>
# In this example we are also extracting an HTML tag of type "span".

# %%
data = []
for i in range(num_results):
    # Extract data for a specific search results
    # We use parenthesis to split the code into multiple lines to keep
    # things organized.
    emory_coursecode = (list_results[i]
                        .find_element('xpath','//span[@class = "result__code"] ')
                        .text)
    emory_coursename  = (list_results[i]
                        .find_element('xpath','//span[@class = "result__title"] ')
                        .text)
    
    # Append data as dictionary
    data.append({"coursecode": emory_coursecode,
                 "coursename": emory_classname})

# Convert to Pandas DataFrame
data_df = pd.DataFrame(data)

data_df
# Out:
#    coursecode                     coursename
# 0      CS 110  Computer Science Fundamentals
# 1      CS 110  Computer Science Fundamentals
# 2      CS 110  Computer Science Fundamentals
# 3      CS 110  Computer Science Fundamentals
# 4      CS 110  Computer Science Fundamentals
# 5      CS 110  Computer Science Fundamentals
# 6      CS 110  Computer Science Fundamentals
# 7      CS 110  Computer Science Fundamentals
# 8      CS 110  Computer Science Fundamentals
# 9      CS 110  Computer Science Fundamentals
# 10     CS 110  Computer Science Fundamentals
# 11     CS 110  Computer Science Fundamentals
# 12     CS 110  Computer Science Fundamentals
# 13     CS 110  Computer Science Fundamentals
# 14     CS 110  Computer Science Fundamentals
# 15     CS 110  Computer Science Fundamentals
# 16     CS 110  Computer Science Fundamentals
# 17     CS 110  Computer Science Fundamentals
# 18     CS 110  Computer Science Fundamentals
# 19     CS 110  Computer Science Fundamentals
# 20     CS 110  Computer Science Fundamentals
# 21     CS 110  Computer Science Fundamentals
# 22     CS 110  Computer Science Fundamentals
# 23     CS 110  Computer Science Fundamentals
# 24     CS 110  Computer Science Fundamentals
# 25     CS 110  Computer Science Fundamentals
# 26     CS 110  Computer Science Fundamentals
# 27     CS 110  Computer Science Fundamentals
# 28     CS 110  Computer Science Fundamentals
# 29     CS 110  Computer Science Fundamentals
# 30     CS 110  Computer Science Fundamentals
# 31     CS 110  Computer Science Fundamentals
# 32     CS 110  Computer Science Fundamentals
# 33     CS 110  Computer Science Fundamentals
# 34     CS 110  Computer Science Fundamentals
# 35     CS 110  Computer Science Fundamentals
# 36     CS 110  Computer Science Fundamentals
# 37     CS 110  Computer Science Fundamentals
# 38     CS 110  Computer Science Fundamentals
# 39     CS 110  Computer Science Fundamentals
# 40     CS 110  Computer Science Fundamentals

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# <font size = "3">
#
# - Expand the dataset above by including the meeting time
# - To do so, browse the Emory Course Atlas website in develop mode <br>
# and find the tag that is used to denote the course meeting time.
# - Try to extract this first for a single element ``` list_results[0] ``` <br>
# and once this is working incorporate it into a loop.
#
#
# Note: In general it's good practice to make sure the code is running <br>
# on a single element before automating the process in a loop.

# %%
# Write your own code

data = []
for i in range(num_results):
    # Extract data for a specific search results
    # We use parenthesis to split the code into multiple lines to keep
    # things organized.
    emory_coursecode = (list_results[i]
                        .find_element('xpath','//span[@class = "result__code"] ')
                        .text)
    emory_coursename  = (list_results[i]
                        .find_element('xpath','//span[@class = "result__title"] ')
                        .text)
    emory_meetingtime  = (list_results[i]
                            .find_element('xpath','/html/body/main/div[2]/div/div[3]/div[4]/a/span[2]/span[3] ')
                            .text)

    # Append data as dictionary
    data.append({"coursecode": emory_coursecode,
                 "coursename": emory_classname,
                 "meetingtime": emory_meetingtime})

# Convert to Pandas DataFrame
data_df = pd.DataFrame(data)

data_df
# Out:
#    coursecode                     coursename          meetingtime
# 0      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 1      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 2      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 3      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 4      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 5      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 6      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 7      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 8      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 9      CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 10     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 11     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 12     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 13     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 14     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 15     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 16     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 17     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 18     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 19     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 20     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 21     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 22     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 23     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 24     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 25     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 26     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 27     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 28     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 29     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 30     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 31     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 32     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 33     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 34     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 35     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 36     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 37     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 38     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 39     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p
# 40     CS 110  Computer Science Fundamentals  Meets:\nTTh 1-2:15p

# %% [markdown]
# # <span style="color:darkblue"> IV. Additional Links </span>
#
# <font size = "5">
#
# More information on Selenium:
#
# https://www.selenium.dev/documentation/overview/
#
# Details on clicking through forms:
#
# https://www.selenium.dev/documentation/webdriver/support_features/select_lists/
